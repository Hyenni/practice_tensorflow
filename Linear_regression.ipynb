# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyenni/practice_tensorflow/blob/master/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Linear Regression
#
# ###Regression analysis techniques that modeling to linear correlation between dependent variable y and one or more independent variable x.

# %% [markdown]
# ###1) Make a sample data

# %%
import tensorflow as tf
import numpy as np

num_data = 1000
sample_data = []
for i in range(num_data):
    x1 = np.random.normal(0.0,0.5)
    y1 = 0.1 * x1 + 0.3 + np.random.normal(0.0,0.02)
    sample_data.append([x1,y1])

# %% [markdown]
# ###2) Print sample data

# %%
import matplotlib.pyplot as plt
x_data = [v[0] for v in sample_data]
y_data = [v[1] for v in sample_data]

plt.plot(x_data, y_data, 'ro', label='Sample data')
plt.legend()
plt.show()

# %% [markdown]
# ###3) Definition Weight, Bias & Expression

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))

y = W * x_data + b

# %% [markdown]
# ###4) Definition Cost Function

# %%
#cost function = loss function = MSE
#y = real data
#y_data = sample data

loss = tf.reduce_mean(tf.square(y-y_data))

# %% [markdown]
# ###5) Definition Optimization Function

# %%
#optimization function : Gradient Descent Optimizer
#learning rate = 0.5

optimizer = tf.train.GradientDescentOptimizer(0.5)

# %% [markdown]
# ###6) Definition train

# %%
#train = loss minimize
#w, b values update

train = optimizer.minimize(loss)

# %% [markdown]
# ###7) Running train

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

#Number of repetitions
num_epochs = 20

#execute
for step in range(num_epochs):
    sess.run(train)
    
    print(step, sess.run(W), sess.run(b), sess.run(loss))
    
    plt.plot(x_data, y_data, 'r*')
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    
    plt.xlabel('x')
    plt.xlim(-2,2)
    plt.ylim(0.1,0.6)
    plt.ylabel('y')
    plt.show()
# Out:
# 0 [-0.05858188] [0.3023349] 0.0065466766
# 1 [-0.01970168] [0.3016284] 0.0038937435
# 2 [0.00962999] [0.30114275] 0.0023839455
# 3 [0.03175753] [0.3007764] 0.0015247102
# 4 [0.04845036] [0.30049998] 0.0010357142
# 5 [0.06104328] [0.30029148] 0.00075742364
# 6 [0.07054327] [0.30013418] 0.0005990468
# 7 [0.07770998] [0.3000155] 0.0005089136
# 8 [0.08311648] [0.29992598] 0.0004576183
# 9 [0.0871951] [0.29985845] 0.0004284258
# 10 [0.09027197] [0.29980752] 0.0004118122
# 11 [0.09259313] [0.29976907] 0.00040235728
# 12 [0.0943442] [0.29974008] 0.00039697642
# 13 [0.09566519] [0.2997182] 0.00039391418
# 14 [0.09666173] [0.29970172] 0.00039217138
# 15 [0.09741352] [0.29968926] 0.00039117958
# 16 [0.09798066] [0.29967988] 0.0003906151
# 17 [0.0984085] [0.29967278] 0.0003902939
# 18 [0.09873126] [0.29966745] 0.00039011112
# 19 [0.09897475] [0.29966342] 0.00039000707
